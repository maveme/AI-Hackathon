# %% [markdown]
# # <h1><center> **Hackathon AI - VU Amsterdam** </center></h1>
# <h2><center><b> HOW TO MAKE A BOT: </b></center></h2>
# <h3><center> A SIMPLE TUTORIAL WITH DIALOGFLOW</center></h3>
#
#
# <br>
# <center><img src="images/bot.jpg" alt="" width="150"/></center>
# <br>
#
# Hi there! I guess you are here to learn how to create an agent for your program that is able to simulate a human activity. Following this tutorial you are going to see that is possible to create such bot (at least the front end part of it) following simple instructions and with no coding. A great tool that allows to experiment with agents is <a href="https://dialogflow.cloud.google.com/">DIALOGFLOW</a>, a Natural Language Processing platform employed to create a platform- and language-specific application relating to client interactions and dialogues for companies.
#
#
# In this tutorial, we are going to create a sample of an agent that takes pizza orders. You will be able to add features to the interaction, experiment with it and test it through the test console that the platform offers. You are going to develop the Speech-to-Text, Text-to-Speech and Speech-to-Speech Recognition part of your application.
# Enough chatting, I don't want you to get bored! :) **Let's get started!**

# %% [markdown]
# ## <u>STEP 1: START WITH DIALOGFLOW</u>
# Initialize DialogFlow, that is, click on the link above and sign in with your Google account. If you do not have a Google account and you do not want to get one, it's lucky day! We created a Google account just for your Hackathon project. Ask any of the organizors the credentials to sign in with it. After signing in and accepting the terms of conditions, you get this interface:
# <br>
# <center><img src="images/1.png" alt="" width="700"/></center>
# <br>
#
# ## <u>STEP 2: CREATE A NEW AGENT</u>
# It's time to create an agent, the main character of our project. Click on the respective button "Create Agent" :
# <br>
# <center><img src="images/2.png" alt="" width="300"/></center>
# <br>
# Change your agent's name in the indicated box. In this case, our agent will be named "PIZZA_BOT". After changing the name, click on the button "Create" and wait for program to initialize it:
#
#
# <br>
# <center><img src="images/3.jpg" alt="" width="700"/></center>
# <br>
# This is the interface you should get now:
#
#
# <br>
# <center><img src="images/4.jpg" alt="" width="700"/></center>
# <br>

# %% [markdown]
# ## <u>STEP 3: DEFINE YOUR PROBLEM</u>
# This step is a more theoretical yet crucial part of this tutorial. Take it as a little introduction to the modeling universe. \
# First, you have to define your problem. That is, what do you want the agent to do?
# Once defined the actions that are going to characterize your bot, think of the input and the output these actions will have. You have to consider what triggers the bot such that an action will happen. Specifically, you are going to be the one creating and manipulating those triggers.
#
# I will now give you an example based on PIZZA_BOT.
# - **What do we want our bot to do?** We want our PIZZA_BOT to take pizza orders from customers calling a pizzeria.
# - **What kind of interaction do we expect?** Our bot will answer the phone like a pizzeria employee. It will ask for customer's name and take the name of the pizza she/he wants to order. It will ask if waiting time is ok and confirm order if customer agrees. The bot will ask for delivery address after order confirmation.
# - **Which data we want to collect?** The main information we want to collect is user name, user address, pizza name and pizza size.
#
# This step is crucial because it gives you a general overview of the human-bot interaction you want to develop.
# Let's go on with the next step.

# %% [markdown]
# ## <u>STEP 4: ENTITIES</u>
# <a href="https://dialogflow.cloud.google.com/">Short definition:</a>
# "Entities are a mechanism in Dialogflow for identifying and extracting useful data from natural-language inputs. [...] are used to pick out specific pieces of information that your users mention—anything from street addresses to product names and amounts with units. Any important data that you want to get from a user's request will have a corresponding entity."
#
# <br>
# <center><img src="images/5.jpg" alt="" width="700"/></center>
# <br>
#
#
# Now, let's define the entities for our project. **Can you guess which of the information defined in the previous step is useful to this purpose?**
#
#
# By definition, we have to consider the useful data we can get from user input. In our case, we defined them to be user_name, user_address, pizza_name, pizza_size.
#
# - **user_name**: This is the entity that will extract our user's name. After changing the entity's name, you start entering "reference values". We can also define synonyms for these values. In this case, since it is not efficient to create a reference value for every single name existing in the world, we will choose the option "Allow for automated expansion", that makes the agent recognize values that were not listed in the entity.
# <br>
# <center><img src="images/6.jpg" alt="" width="700"/></center>
# <br>
#
# - **user_address**: The method to define this entity is the same as the one defined above. Try by yourself, don't be scared to play with the platform and become more confident with the skills you're getting with this tutorial.
# - **pizza_name**: This is the entity that will extract the name of the pizza the customer will like to order. In this case, we look at our pizzeria's menu and we see which pizza our bot can propose to the customer. In this case we do not allow for automated expansion since the customer can choose only one of the pizza names available in our menu.
# <br>
# <center><img src="images/7.jpg" alt="" width="700"/></center>
# <br>
#
# - **pizza_size**: The procedure for this entity is the same as above. Again, try by yourself.

# %% [markdown]
# ## <u>STEP 4: INTENTS</u>
# First of all, congratulations on making it this far. You're doing an amazing job! The next step is about creating intents for our agent.
#
#
# <a href="https://cloud.google.com/dialogflow/es/docs/intents-overview?hl=en">Short definition:</a>
# "An intent categorizes an end-user's intention for one conversation turn. For each agent, you define many intents, where your combined intents can handle a complete conversation. When an end-user writes or says something, referred to as an end-user expression, Dialogflow matches the end-user expression to the best intent in your agent. Matching an intent is also known as intent classification."
#
# For our project, we need different intents:
# - a customized **welcome intent**, that makes the bot answer the call as a pizzeria employee
# - a **pizza_call intent**, that asks for customer's name and the asks the customer how it can help.
# - a **pizza intent**, that gets the information relative to the pizza the customer wants to order (pizza_name and pizza_size). It then confirms the order and tells the customer the expected waiting time and ask if that's okay for the customer.
# - a **no intent**, if the customer does not want to wait that much time. The bot then ends the conversation politely.
# - a **yes intent**, if the customer wants to wait that much time. At this point, the agent takes the information relative to customer's address. Then it ends the conversation.
#
#
# Before we start creating new intents, delete the default welcome one.
# <br>
# <center><img src="images/8.jpg" alt="" width="700"/></center>
# <br>
#
# The first intent we want to create is named **Welcome**. In this case we want the intent to be triggered without the need for matched text or spoken input. We can do this by using one of the default **events** on the platform, in this case the "welcome" event.
# We also want the agent to deliver a text rich **response** to the user, "Hi, thank you for calling pizzeria Italia!".
# <br>
# <center><img src="images/9.jpg" alt="" width="700"/></center>
# <br>
#
# It's now time to get to the core intents of our interaction.\
# The second intent it's going to be named **Pizza_Call**. This intent will be triggered by some sentences that we expect the customer to say.  The set of the triggering sentences is represented by "Training Phrases".
# <br>
# <center><img src="images/10.jpg" alt="" width="700"/></center>
# <br>
#
# Now we start defining **actions** for our intents. You can define an action for each intent. When an intent is matched, Dialogflow provides the action to your system, and you can use the action to trigger certain actions defined in your system. For each action we also define a **parameter**. When an intent is matched at runtime, Dialogflow provides the extracted values from the end-user expression as parameters. Each parameter has a type, called the entity type, which dictates exactly how the data is extracted. Unlike raw end-user input, parameters are structured data that can easily be used to perform some logic or generate responses. Our parameter will be required, so that our intent will be incompleted without the corresponding parameter. In the **prompts**, we write the questions the agent will ask user if a request does not contain this parameter. In our case, the questions are going to ask for user name and store the information in the parameter user_name.   We also define the message the agent will deliver to the user.
# <br>
# <center><img src="images/11.jpg" alt="" width="700"/></center>
# <br>
#
# Start testing your code in the test console. Remember that after the first welcome intent, you have to trigger Pizza_Call using one of the training phrases. Try also to type something that you did not add in the training expressions to see the agent's reaction. Does it use any default intent?

# %% [markdown]
# ## <u>STEP 5: ADD FOLLOW-UP INTENTS TO CREATE A CONVERSATION</u>
# You can see that we still have some intents to define. Well, these are going to be slightly different from the previous ones since they are going to be added as follow-ups. That is, we set by default that they come next with respect to another intent. I am going to show you how to add a follow-up intent and then rest of the procedure is the same as in the step above.
# <br>
# <center><img src="images/12.jpeg" alt="" width="300"/></center>
# <br>
# <br>
# <center><img src="images/13.jpeg" alt="" width="300"/></center>
# <br>
#
# Our follow-up intent will be **Pizza**. The procedure is the same as above. I will show you the interface you should get after following the instructions.
# <br>
# <center><img src="images/14.jpg" alt="" width="700"/></center>
# <br>
# <br>
# <center><img src="images/15.jpg" alt="" width="700"/></center>
# <br>
#
# Keep testing the agent with the test console and enjoy the progresses you made so far! Remember to trigger the intents with the right training phrases.
#
#
# At this point, we see that our bot asked if the waiting time is ok for the customer. We should then add two follow-ups to the Pizza intent. In this case we do not select "next" as follow-up type, but we select "yes" and "no" respectively!
# One if customer answers somehow no and ther other if customer says yes. If **no intent** is triggered, the bot will say bye to the customer and end the conversation (we enable the option "Set this intent as the end of the conversation" at the bottom of the page). If **yes intent** is triggered, the bot will ask the customer for delivery address and close the conversation (enabling the same option as before).
#
# - **no intent**:
# <br>
# <center><img src="images/16.jpg" alt="" width="700"/></center>
# <br>
# <br>
# <center><img src="images/17.jpg" alt="" width="700"/></center>
# <br>
#
# - **yes intent**:
# <br>
# <center><img src="images/18.jpg" alt="" width="700"/></center>
# <br>
# <br>
# <center><img src="images/19.jpg" alt="" width="700"/></center>
# <br>
#
# And that's it! Our bot is finished! Of course, you can modify the agent and add as many features as you want. Or you can create a new one, now that you know how! Don't be scared to experiment and have a look at the "Prebuilt Agents" section to take some inspiration.
#
#
# In the final step, we are going to finalize our bot's characteristics.

# %% [markdown]
# ## <u>STEP 6: HAVE SOME FUN TESTING YOUR AGENT!</u>
# Dialogflow offers many different ways to test your agent. First of all, change the **Speech Settings** of your agent.
# <br>
# <center><img src="images/21.jpg" alt="" width="700"/></center>
# <br>
# After that, you can try out Dialogflow's Integrations. They give you the chance to test your bot in different environments (phone call, telegram, facebook messanger, etc.). In this case, the best environment to test our bot is the Dialogflow Phone Gateway, which generates a phone number that you can call from your phone. Guess what? The bot is going to pick up the call and you are going to have a call with it. Try to call the number in the picture and have some fun with it!
# <br>
# <center><img src="images/20.jpg" alt="" width="700"/></center>
# <br>
# You can also try the speech functions from the test console, just clicking on the microphone button. You are going to receive audio messages from your agent as well.
#
#
# Wow, looks like we are done here...
#
#
# # <h1><center> **THANK YOU FOR YOUR TIME** </center></h1>
# # <h1><center> **KEEP GOING WITH YOUR PROJECT AND GOOD LUCK!!!** </center></h1>

# %% [markdown]
# ---
#
# &copy; 2022 - **VU Amsterdam**
